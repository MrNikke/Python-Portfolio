# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
hki = pd.read_csv("Vantaa Helsinki-Vantaan lentoasema_ 1.1.1990 - 19.2.2025.csv",na_values="-")

# %%
hki.head()
# Out:
#                         Havaintoasema  Vuosi  Kuukausi  Päivä  \
# 0  Vantaa Helsinki-Vantaan lentoasema   1990         1      1
# 1  Vantaa Helsinki-Vantaan lentoasema   1990         1      1
# 2  Vantaa Helsinki-Vantaan lentoasema   1990         1      2
# 3  Vantaa Helsinki-Vantaan lentoasema   1990         1      2
# 4  Vantaa Helsinki-Vantaan lentoasema   1990         1      3
#
#   Aika [Paikallinen aika]  Sademäärä [mm]  Lumensyvyys [cm]  \
# 0                   02:00             0.1               8.0
# 1                   07:40             NaN               NaN
# 2                   02:00             0.1               8.0
# 3                   07:40             NaN               NaN
# 4                   02:00             0.2               8.0
#
#    Ilman keskilämpötila [°C]  Maanpintaminimi [°C]  Ylin lämpötila [°C]  \
# 0                       -5.4                   NaN                 -2.1
# 1                        NaN                 -13.3                  NaN
# 2                       -4.6                   NaN                 -3.0
# 3                        NaN                  -4.4                  NaN
# 4                      -12.3                   NaN                 -4.7
#
#    Alin lämpötila [°C]
# 0                 -8.9
# 1                  NaN
# 2                 -6.0
# 3                  NaN
# 4                -16.6

# %%
hki.apply(pd.isnull).sum()
# Out:
# Havaintoasema                    0
# Vuosi                            0
# Kuukausi                         0
# Päivä                            0
# Aika [Paikallinen aika]          0
# Sademäärä [mm]               11726
# Lumensyvyys [cm]             11730
# Ilman keskilämpötila [°C]    11726
# Maanpintaminimi [°C]         12839
# Ylin lämpötila [°C]          11730
# Alin lämpötila [°C]          11730
# dtype: int64

# %%
null_pct = hki.apply(pd.isnull).sum()/hki.shape[0]
null_pct
# Out:
# Havaintoasema                0.000000
# Vuosi                        0.000000
# Kuukausi                     0.000000
# Päivä                        0.000000
# Aika [Paikallinen aika]      0.000000
# Sademäärä [mm]               0.477462
# Lumensyvyys [cm]             0.477625
# Ilman keskilämpötila [°C]    0.477462
# Maanpintaminimi [°C]         0.522782
# Ylin lämpötila [°C]          0.477625
# Alin lämpötila [°C]          0.477625
# dtype: float64

# %%
hki.head()
# Out:
#                         Havaintoasema  Vuosi  Kuukausi  Päivä  \
# 0  Vantaa Helsinki-Vantaan lentoasema   1990         1      1
# 1  Vantaa Helsinki-Vantaan lentoasema   1990         1      1
# 2  Vantaa Helsinki-Vantaan lentoasema   1990         1      2
# 3  Vantaa Helsinki-Vantaan lentoasema   1990         1      2
# 4  Vantaa Helsinki-Vantaan lentoasema   1990         1      3
#
#   Aika [Paikallinen aika]  Sademäärä [mm]  Lumensyvyys [cm]  \
# 0                   02:00             0.1               8.0
# 1                   07:40             NaN               NaN
# 2                   02:00             0.1               8.0
# 3                   07:40             NaN               NaN
# 4                   02:00             0.2               8.0
#
#    Ilman keskilämpötila [°C]  Maanpintaminimi [°C]  Ylin lämpötila [°C]  \
# 0                       -5.4                   NaN                 -2.1
# 1                        NaN                 -13.3                  NaN
# 2                       -4.6                   NaN                 -3.0
# 3                        NaN                  -4.4                  NaN
# 4                      -12.3                   NaN                 -4.7
#
#    Alin lämpötila [°C]
# 0                 -8.9
# 1                  NaN
# 2                 -6.0
# 3                  NaN
# 4                -16.6

# %%
group_cols = ["Havaintoasema", "Vuosi", "Kuukausi", "Päivä"]

# %%
hki_combined = hki.groupby(group_cols, as_index=False).apply(lambda g: g.bfill().iloc[0])
# Out:
# C:\Users\nikla\AppData\Local\Temp\ipykernel_20896\1153265893.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   hki_combined = hki.groupby(group_cols, as_index=False).apply(lambda g: g.bfill().iloc[0])

# %%
hki_combined.reset_index(drop=True, inplace=True)

# %%
hki_combined
# Out:
#                             Havaintoasema  Vuosi  Kuukausi  Päivä  \
# 0      Vantaa Helsinki-Vantaan lentoasema   1990         1      1
# 1      Vantaa Helsinki-Vantaan lentoasema   1990         1      2
# 2      Vantaa Helsinki-Vantaan lentoasema   1990         1      3
# 3      Vantaa Helsinki-Vantaan lentoasema   1990         1      4
# 4      Vantaa Helsinki-Vantaan lentoasema   1990         1      5
# ...                                   ...    ...       ...    ...
# 12829  Vantaa Helsinki-Vantaan lentoasema   2025         2     15
# 12830  Vantaa Helsinki-Vantaan lentoasema   2025         2     16
# 12831  Vantaa Helsinki-Vantaan lentoasema   2025         2     17
# 12832  Vantaa Helsinki-Vantaan lentoasema   2025         2     18
# 12833  Vantaa Helsinki-Vantaan lentoasema   2025         2     19
#
#       Aika [Paikallinen aika]  Sademäärä [mm]  Lumensyvyys [cm]  \
# 0                       02:00             0.1               8.0
# 1                       02:00             0.1               8.0
# 2                       02:00             0.2               8.0
# 3                       02:00             1.7               8.0
# 4                       02:00             0.0              10.0
# ...                       ...             ...               ...
# 12829                   02:00            -1.0               2.0
# 12830                   02:00             2.3               2.0
# 12831                   02:00            -1.0               7.0
# 12832                   02:00             0.3               6.0
# 12833                   02:00             NaN               5.0
#
#        Ilman keskilämpötila [°C]  Maanpintaminimi [°C]  Ylin lämpötila [°C]  \
# 0                           -5.4                 -13.3                 -2.1
# 1                           -4.6                  -4.4                 -3.0
# 2                          -12.3                 -13.5                 -4.7
# 3                           -4.4                 -19.4                 -1.4
# 4                           -1.0                  -1.5                 -0.2
# ...                          ...                   ...                  ...
# 12829                       -8.4                   NaN                 -6.2
# 12830                      -10.7                   NaN                 -6.7
# 12831                       -8.4                   NaN                 -4.7
# 12832                       -5.8                   NaN                 -1.7
# 12833                        NaN                   NaN                  NaN
#
#        Alin lämpötila [°C]
# 0                     -8.9
# 1                     -6.0
# 2                    -16.6
# 3                    -17.5
# 4                     -1.8
# ...                    ...
# 12829                -12.5
# 12830                -16.2
# 12831                -13.1
# 12832                -14.7
# 12833                  NaN
#
# [12834 rows x 11 columns]

# %%
hki_combined.apply(pd.isnull).sum()
# Out:
# Havaintoasema                   0
# Vuosi                           0
# Kuukausi                        0
# Päivä                           0
# Aika [Paikallinen aika]         0
# Sademäärä [mm]                  1
# Lumensyvyys [cm]                5
# Ilman keskilämpötila [°C]       1
# Maanpintaminimi [°C]         1114
# Ylin lämpötila [°C]             5
# Alin lämpötila [°C]             5
# dtype: int64

# %%
null_pct2 = hki_combined.apply(pd.isnull).sum()/hki_combined.shape[0]
null_pct2
# Out:
# Havaintoasema                0.000000
# Vuosi                        0.000000
# Kuukausi                     0.000000
# Päivä                        0.000000
# Aika [Paikallinen aika]      0.000000
# Sademäärä [mm]               0.000078
# Lumensyvyys [cm]             0.000390
# Ilman keskilämpötila [°C]    0.000078
# Maanpintaminimi [°C]         0.086801
# Ylin lämpötila [°C]          0.000390
# Alin lämpötila [°C]          0.000390
# dtype: float64

# %%
valid_columns = hki_combined.columns[null_pct2 < 0.05]

# %%
valid_columns
# Out:
# Index(['Havaintoasema', 'Vuosi', 'Kuukausi', 'Päivä',
#        'Aika [Paikallinen aika]', 'Sademäärä [mm]', 'Lumensyvyys [cm]',
#        'Ilman keskilämpötila [°C]', 'Ylin lämpötila [°C]',
#        'Alin lämpötila [°C]'],
#       dtype='object')

# %%
hki = hki_combined[valid_columns].copy()

# %%
hki.apply(pd.isnull).sum()
# Out:
# Havaintoasema                0
# Vuosi                        0
# Kuukausi                     0
# Päivä                        0
# Aika [Paikallinen aika]      0
# Sademäärä [mm]               1
# Lumensyvyys [cm]             5
# Ilman keskilämpötila [°C]    1
# Ylin lämpötila [°C]          5
# Alin lämpötila [°C]          5
# dtype: int64

# %%
hki.head()
# Out:
#                         Havaintoasema  Vuosi  Kuukausi  Päivä  \
# 0  Vantaa Helsinki-Vantaan lentoasema   1990         1      1
# 1  Vantaa Helsinki-Vantaan lentoasema   1990         1      2
# 2  Vantaa Helsinki-Vantaan lentoasema   1990         1      3
# 3  Vantaa Helsinki-Vantaan lentoasema   1990         1      4
# 4  Vantaa Helsinki-Vantaan lentoasema   1990         1      5
#
#   Aika [Paikallinen aika]  Sademäärä [mm]  Lumensyvyys [cm]  \
# 0                   02:00             0.1               8.0
# 1                   02:00             0.1               8.0
# 2                   02:00             0.2               8.0
# 3                   02:00             1.7               8.0
# 4                   02:00             0.0              10.0
#
#    Ilman keskilämpötila [°C]  Ylin lämpötila [°C]  Alin lämpötila [°C]
# 0                       -5.4                 -2.1                 -8.9
# 1                       -4.6                 -3.0                 -6.0
# 2                      -12.3                 -4.7                -16.6
# 3                       -4.4                 -1.4                -17.5
# 4                       -1.0                 -0.2                 -1.8

# %%
hki = hki.ffill()

# %%
hki.apply(pd.isnull).sum()
# Out:
# Havaintoasema                0
# Vuosi                        0
# Kuukausi                     0
# Päivä                        0
# Aika [Paikallinen aika]      0
# Sademäärä [mm]               0
# Lumensyvyys [cm]             0
# Ilman keskilämpötila [°C]    0
# Ylin lämpötila [°C]          0
# Alin lämpötila [°C]          0
# dtype: int64

# %%
hki.dtypes
# Out:
# Havaintoasema                 object
# Vuosi                          int64
# Kuukausi                       int64
# Päivä                          int64
# Aika [Paikallinen aika]       object
# Sademäärä [mm]               float64
# Lumensyvyys [cm]             float64
# Ilman keskilämpötila [°C]    float64
# Ylin lämpötila [°C]          float64
# Alin lämpötila [°C]          float64
# dtype: object

# %%
hki.index
# Out:
# RangeIndex(start=0, stop=12834, step=1)

# %%
hki.Vuosi.value_counts().sort_index()
# Out:
# Vuosi
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# 2024    366
# 2025     50
# Name: count, dtype: int64

# %%
hki["Lumensyvyys [cm]"].plot()
# Out:
# <Axes: >

# %%
hki['date'] = pd.to_datetime(hki['Vuosi'].astype(str) + '-' + 
                              hki['Kuukausi'].astype(str) + '-' + 
                              hki['Päivä'].astype(str))

# Optionally, drop the separate columns if you no longer need them:
hki.drop(columns=['Vuosi', 'Kuukausi', 'Päivä'], inplace=True)

# %%
hki['date'] = pd.to_datetime(hki['date'])
hki.set_index('date', inplace=True)

# %%
hki.index
# Out:
# DatetimeIndex(['1990-01-01', '1990-01-02', '1990-01-03', '1990-01-04',
#                '1990-01-05', '1990-01-06', '1990-01-07', '1990-01-08',
#                '1990-01-09', '1990-01-10',
#                ...
#                '2025-02-10', '2025-02-11', '2025-02-12', '2025-02-13',
#                '2025-02-14', '2025-02-15', '2025-02-16', '2025-02-17',
#                '2025-02-18', '2025-02-19'],
#               dtype='datetime64[ns]', name='date', length=12834, freq=None)

# %%
hki["Lumensyvyys [cm]"].plot()
# Out:
# <Axes: xlabel='date'>

# %%
hki.loc["1990-01":"2025-12","Ilman keskilämpötila [°C]"].plot()
# Out:
# <Axes: xlabel='date'>

# %%
sns.scatterplot(x="Ilman keskilämpötila [°C]", y="Sademäärä [mm]", data=hki, hue="Lumensyvyys [cm]")
# Out:
# <Axes: xlabel='Ilman keskilämpötila [°C]', ylabel='Sademäärä [mm]'>

# %%
hki.dtypes
# Out:
# Havaintoasema                 object
# Aika [Paikallinen aika]       object
# Sademäärä [mm]               float64
# Lumensyvyys [cm]             float64
# Ilman keskilämpötila [°C]    float64
# Ylin lämpötila [°C]          float64
# Alin lämpötila [°C]          float64
# dtype: object

# %%
hki.head()
# Out:
#                                  Havaintoasema Aika [Paikallinen aika]  \
# date
# 1990-01-01  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-02  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-03  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-04  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-05  Vantaa Helsinki-Vantaan lentoasema                   02:00
#
#             Sademäärä [mm]  Lumensyvyys [cm]  Ilman keskilämpötila [°C]  \
# date
# 1990-01-01             0.1               8.0                       -5.4
# 1990-01-02             0.1               8.0                       -4.6
# 1990-01-03             0.2               8.0                      -12.3
# 1990-01-04             1.7               8.0                       -4.4
# 1990-01-05             0.0              10.0                       -1.0
#
#             Ylin lämpötila [°C]  Alin lämpötila [°C]
# date
# 1990-01-01                 -2.1                 -8.9
# 1990-01-02                 -3.0                 -6.0
# 1990-01-03                 -4.7                -16.6
# 1990-01-04                 -1.4                -17.5
# 1990-01-05                 -0.2                 -1.8

# %%
hki["Target"] = hki.shift(-1)["Ylin lämpötila [°C]"]

# %%
hki
# Out:
#                                  Havaintoasema Aika [Paikallinen aika]  \
# date
# 1990-01-01  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-02  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-03  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-04  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-05  Vantaa Helsinki-Vantaan lentoasema                   02:00
# ...                                        ...                     ...
# 2025-02-15  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-16  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-17  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-18  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-19  Vantaa Helsinki-Vantaan lentoasema                   02:00
#
#             Sademäärä [mm]  Lumensyvyys [cm]  Ilman keskilämpötila [°C]  \
# date
# 1990-01-01             0.1               8.0                       -5.4
# 1990-01-02             0.1               8.0                       -4.6
# 1990-01-03             0.2               8.0                      -12.3
# 1990-01-04             1.7               8.0                       -4.4
# 1990-01-05             0.0              10.0                       -1.0
# ...                    ...               ...                        ...
# 2025-02-15            -1.0               2.0                       -8.4
# 2025-02-16             2.3               2.0                      -10.7
# 2025-02-17            -1.0               7.0                       -8.4
# 2025-02-18             0.3               6.0                       -5.8
# 2025-02-19             0.3               5.0                       -5.8
#
#             Ylin lämpötila [°C]  Alin lämpötila [°C]  Target
# date
# 1990-01-01                 -2.1                 -8.9    -3.0
# 1990-01-02                 -3.0                 -6.0    -4.7
# 1990-01-03                 -4.7                -16.6    -1.4
# 1990-01-04                 -1.4                -17.5    -0.2
# 1990-01-05                 -0.2                 -1.8    -1.5
# ...                         ...                  ...     ...
# 2025-02-15                 -6.2                -12.5    -6.7
# 2025-02-16                 -6.7                -16.2    -4.7
# 2025-02-17                 -4.7                -13.1    -1.7
# 2025-02-18                 -1.7                -14.7    -1.7
# 2025-02-19                 -1.7                -14.7     NaN
#
# [12834 rows x 8 columns]

# %%
hki = hki.ffill()

# %%
hki.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12834 entries, 1990-01-01 to 2025-02-19
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Havaintoasema              12834 non-null  object
#  1   Aika [Paikallinen aika]    12834 non-null  object
#  2   Sademäärä [mm]             12834 non-null  float64
#  3   Lumensyvyys [cm]           12834 non-null  float64
#  4   Ilman keskilämpötila [°C]  12834 non-null  float64
#  5   Ylin lämpötila [°C]        12834 non-null  float64
#  6   Alin lämpötila [°C]        12834 non-null  float64
#  7   Target                     12834 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 1.4+ MB

# %%
hki.to_csv("Weather_cleaned_data")

# %%
hki
# Out:
#                                  Havaintoasema Aika [Paikallinen aika]  \
# date
# 1990-01-01  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-02  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-03  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-04  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-05  Vantaa Helsinki-Vantaan lentoasema                   02:00
# ...                                        ...                     ...
# 2025-02-15  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-16  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-17  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-18  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-19  Vantaa Helsinki-Vantaan lentoasema                   02:00
#
#             Sademäärä [mm]  Lumensyvyys [cm]  Ilman keskilämpötila [°C]  \
# date
# 1990-01-01             0.1               8.0                       -5.4
# 1990-01-02             0.1               8.0                       -4.6
# 1990-01-03             0.2               8.0                      -12.3
# 1990-01-04             1.7               8.0                       -4.4
# 1990-01-05             0.0              10.0                       -1.0
# ...                    ...               ...                        ...
# 2025-02-15            -1.0               2.0                       -8.4
# 2025-02-16             2.3               2.0                      -10.7
# 2025-02-17            -1.0               7.0                       -8.4
# 2025-02-18             0.3               6.0                       -5.8
# 2025-02-19             0.3               5.0                       -5.8
#
#             Ylin lämpötila [°C]  Alin lämpötila [°C]  Target
# date
# 1990-01-01                 -2.1                 -8.9    -3.0
# 1990-01-02                 -3.0                 -6.0    -4.7
# 1990-01-03                 -4.7                -16.6    -1.4
# 1990-01-04                 -1.4                -17.5    -0.2
# 1990-01-05                 -0.2                 -1.8    -1.5
# ...                         ...                  ...     ...
# 2025-02-15                 -6.2                -12.5    -6.7
# 2025-02-16                 -6.7                -16.2    -4.7
# 2025-02-17                 -4.7                -13.1    -1.7
# 2025-02-18                 -1.7                -14.7    -1.7
# 2025-02-19                 -1.7                -14.7    -1.7
#
# [12834 rows x 8 columns]

# %%
corr_matrix = hki.corr(numeric_only=True)
corr_matrix
# Out:
#                            Sademäärä [mm]  Lumensyvyys [cm]  \
# Sademäärä [mm]                   1.000000         -0.029691
# Lumensyvyys [cm]                -0.029691          1.000000
# Ilman keskilämpötila [°C]        0.033586         -0.517364
# Ylin lämpötila [°C]             -0.011120         -0.500754
# Alin lämpötila [°C]              0.085365         -0.522822
# Target                          -0.011945         -0.491962
#
#                            Ilman keskilämpötila [°C]  Ylin lämpötila [°C]  \
# Sademäärä [mm]                              0.033586            -0.011120
# Lumensyvyys [cm]                           -0.517364            -0.500754
# Ilman keskilämpötila [°C]                   1.000000             0.982992
# Ylin lämpötila [°C]                         0.982992             1.000000
# Alin lämpötila [°C]                         0.961170             0.912381
# Target                                      0.953749             0.963011
#
#                            Alin lämpötila [°C]    Target
# Sademäärä [mm]                        0.085365 -0.011945
# Lumensyvyys [cm]                     -0.522822 -0.491962
# Ilman keskilämpötila [°C]             0.961170  0.953749
# Ylin lämpötila [°C]                   0.912381  0.963011
# Alin lämpötila [°C]                   1.000000  0.879133
# Target                                0.879133  1.000000

# %%
sns.heatmap(corr_matrix, annot=True)
# Out:
# <Axes: >

# %%
from sklearn.linear_model import Ridge
rr = Ridge(alpha=.1)

# %%
# predictors = hki.columns[~hki.columns.isin(["Target", "Havaintoasema","Aika [Paikallinen aika]"])]
predictors = [
    "Sademäärä [mm]",
    "Lumensyvyys [cm]",
    "Ilman keskilämpötila [°C]",
    "Ylin lämpötila [°C]",
    "Alin lämpötila [°C]"
]

# %%
predictors
# Out:
# ['Sademäärä [mm]',
#  'Lumensyvyys [cm]',
#  'Ilman keskilämpötila [°C]',
#  'Ylin lämpötila [°C]',
#  'Alin lämpötila [°C]']

# %%
def backtest(weather, model, predictors, start=3650, step=90):
    all_predictions = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
        
        model.fit(train[predictors], train["Target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["Target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(hki, rr, predictors)

# %%
predictions
# Out:
#             actual  prediction      diff
# date
# 2000-01-13     3.1    4.634485  1.534485
# 2000-01-14    -1.3    2.689815  3.989815
# 2000-01-15     2.0   -0.394274  2.394274
# 2000-01-16     2.0    2.964782  0.964782
# 2000-01-17     0.0    2.543068  2.543068
# ...            ...         ...       ...
# 2025-02-15    -6.7   -4.824865  1.875135
# 2025-02-16    -4.7   -5.830962  1.130962
# 2025-02-17    -1.7   -3.983849  2.283849
# 2025-02-18    -1.7    0.142374  1.842374
# 2025-02-19    -1.7    0.152478  1.852478
#
# [9170 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 1.947062422864101

# %%
predictions["diff"].mean()
# Out:
# 1.947062422864101

# %%
def pct_diff(old, new):
    return (new - old) / old

def compute_rolling(hki, horizon, col):
    label = f"rolling_{horizon}_{col}"
    hki[label] = hki[col].rolling(horizon).mean()
    hki[f"{label}_pct"] = pct_diff(hki[label], hki[col])
    return hki
    
rolling_horizons = [3, 14]
for horizon in rolling_horizons:
    for col in ["Sademäärä [mm]", "Lumensyvyys [cm]", "Ilman keskilämpötila [°C]","Ylin lämpötila [°C]", "Alin lämpötila [°C]"]:
        hki = compute_rolling(hki, horizon, col)

# %%
hki
# Out:
#                                  Havaintoasema Aika [Paikallinen aika]  \
# date
# 1990-01-15  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-16  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-17  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-18  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-19  Vantaa Helsinki-Vantaan lentoasema                   02:00
# ...                                        ...                     ...
# 2025-02-15  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-16  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-17  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-18  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-19  Vantaa Helsinki-Vantaan lentoasema                   02:00
#
#             Sademäärä [mm]  Lumensyvyys [cm]  Ilman keskilämpötila [°C]  \
# date
# 1990-01-15            11.0              29.0                       -8.9
# 1990-01-16             0.3              34.0                       -2.7
# 1990-01-17             3.8              34.0                       -3.3
# 1990-01-18             0.1              32.0                       -2.0
# 1990-01-19             0.6              32.0                      -13.9
# ...                    ...               ...                        ...
# 2025-02-15            -1.0               2.0                       -8.4
# 2025-02-16             2.3               2.0                      -10.7
# 2025-02-17            -1.0               7.0                       -8.4
# 2025-02-18             0.3               6.0                       -5.8
# 2025-02-19             0.3               5.0                       -5.8
#
#             Ylin lämpötila [°C]  Alin lämpötila [°C]  Target  \
# date
# 1990-01-15                 -2.5                -20.5     0.3
# 1990-01-16                  0.3                 -5.8     2.3
# 1990-01-17                  2.3                 -7.8     2.9
# 1990-01-18                  2.9                 -8.3    -7.6
# 1990-01-19                 -7.6                -17.9     1.6
# ...                         ...                  ...     ...
# 2025-02-15                 -6.2                -12.5    -6.7
# 2025-02-16                 -6.7                -16.2    -4.7
# 2025-02-17                 -4.7                -13.1    -1.7
# 2025-02-18                 -1.7                -14.7    -1.7
# 2025-02-19                 -1.7                -14.7    -1.7
#
#             rolling_3_Sademäärä [mm]  rolling_3_Sademäärä [mm]_pct  ...  \
# date                                                                ...
# 1990-01-15                       NaN                           NaN  ...
# 1990-01-16                       NaN                           NaN  ...
# 1990-01-17                  5.033333                     -0.245033  ...
# 1990-01-18                  1.400000                     -0.928571  ...
# 1990-01-19                  1.500000                     -0.600000  ...
# ...                              ...                           ...  ...
# 2025-02-15                 -1.000000                     -0.000000  ...
# 2025-02-16                  0.100000                     22.000000  ...
# 2025-02-17                  0.100000                    -11.000000  ...
# 2025-02-18                  0.533333                     -0.437500  ...
# 2025-02-19                 -0.133333                     -3.250000  ...
#
#             month_avg_Sademäärä [mm]  day_avg_Sademäärä [mm]  \
# date
# 1990-01-15                 11.000000               11.000000
# 1990-01-16                  5.650000                0.300000
# 1990-01-17                  5.033333                3.800000
# 1990-01-18                  3.800000                0.100000
# 1990-01-19                  3.160000                0.600000
# ...                              ...                     ...
# 2025-02-15                  1.409462                1.305556
# 2025-02-16                  1.410348                2.227778
# 2025-02-17                  1.407952                1.936111
# 2025-02-18                  1.406852                0.638889
# 2025-02-19                  1.405754                1.305556
#
#             month_avg_Lumensyvyys [cm]  day_avg_Lumensyvyys [cm]  \
# date
# 1990-01-15                   29.000000                 29.000000
# 1990-01-16                   31.500000                 34.000000
# 1990-01-17                   32.333333                 34.000000
# 1990-01-18                   32.250000                 32.000000
# 1990-01-19                   32.200000                 32.000000
# ...                                ...                       ...
# 2025-02-15                   22.607570                 22.000000
# 2025-02-16                   22.587065                 22.194444
# 2025-02-17                   22.571571                 23.000000
# 2025-02-18                   22.555114                 23.833333
# 2025-02-19                   22.537698                 23.722222
#
#             month_avg_Ilman keskilämpötila [°C]  \
# date
# 1990-01-15                            -8.900000
# 1990-01-16                            -5.800000
# 1990-01-17                            -4.966667
# 1990-01-18                            -4.225000
# 1990-01-19                            -6.160000
# ...                                         ...
# 2025-02-15                            -4.533665
# 2025-02-16                            -4.539801
# 2025-02-17                            -4.543638
# 2025-02-18                            -4.544886
# 2025-02-19                            -4.546131
#
#             day_avg_Ilman keskilämpötila [°C]  month_avg_Ylin lämpötila [°C]  \
# date
# 1990-01-15                          -8.900000                      -2.500000
# 1990-01-16                          -2.700000                      -1.100000
# 1990-01-17                          -3.300000                       0.033333
# 1990-01-18                          -2.000000                       0.750000
# 1990-01-19                         -13.900000                      -0.920000
# ...                                       ...                            ...
# 2025-02-15                          -4.325000                      -1.727092
# 2025-02-16                          -4.227778                      -1.732040
# 2025-02-17                          -4.336111                      -1.734990
# 2025-02-18                          -5.130556                      -1.734955
# 2025-02-19                          -4.747222                      -1.734921
#
#             day_avg_Ylin lämpötila [°C]  month_avg_Alin lämpötila [°C]  \
# date
# 1990-01-15                    -2.500000                     -20.500000
# 1990-01-16                     0.300000                     -13.150000
# 1990-01-17                     2.300000                     -11.366667
# 1990-01-18                     2.900000                     -10.600000
# 1990-01-19                    -7.600000                     -12.060000
# ...                                 ...                            ...
# 2025-02-15                    -1.380556                      -7.598108
# 2025-02-16                    -1.766667                      -7.606667
# 2025-02-17                    -1.513889                      -7.612127
# 2025-02-18                    -1.858333                      -7.619166
# 2025-02-19                    -1.900000                      -7.626190
#
#             day_avg_Alin lämpötila [°C]
# date
# 1990-01-15                   -20.500000
# 1990-01-16                    -5.800000
# 1990-01-17                    -7.800000
# 1990-01-18                    -8.300000
# 1990-01-19                   -17.900000
# ...                                 ...
# 2025-02-15                    -7.150000
# 2025-02-16                    -7.141667
# 2025-02-17                    -6.797222
# 2025-02-18                    -8.925000
# 2025-02-19                    -8.105556
#
# [12820 rows x 38 columns]

# %%
hki = hki.iloc[14:,:]

# %%
hki
# Out:
#                                  Havaintoasema Aika [Paikallinen aika]  \
# date
# 1990-01-29  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-30  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-31  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-02-01  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-02-02  Vantaa Helsinki-Vantaan lentoasema                   02:00
# ...                                        ...                     ...
# 2025-02-15  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-16  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-17  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-18  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-19  Vantaa Helsinki-Vantaan lentoasema                   02:00
#
#             Sademäärä [mm]  Lumensyvyys [cm]  Ilman keskilämpötila [°C]  \
# date
# 1990-01-29             2.3              33.0                        1.3
# 1990-01-30             0.6              29.0                        0.7
# 1990-01-31             3.4              29.0                        1.1
# 1990-02-01             0.5              26.0                        2.2
# 1990-02-02             3.8              23.0                        2.3
# ...                    ...               ...                        ...
# 2025-02-15            -1.0               2.0                       -8.4
# 2025-02-16             2.3               2.0                      -10.7
# 2025-02-17            -1.0               7.0                       -8.4
# 2025-02-18             0.3               6.0                       -5.8
# 2025-02-19             0.3               5.0                       -5.8
#
#             Ylin lämpötila [°C]  Alin lämpötila [°C]  Target  \
# date
# 1990-01-29                  2.6                 -0.4     2.0
# 1990-01-30                  2.0                 -0.4     2.2
# 1990-01-31                  2.2                 -0.1     3.6
# 1990-02-01                  3.6                  1.2     3.2
# 1990-02-02                  3.2                  1.3     2.5
# ...                         ...                  ...     ...
# 2025-02-15                 -6.2                -12.5    -6.7
# 2025-02-16                 -6.7                -16.2    -4.7
# 2025-02-17                 -4.7                -13.1    -1.7
# 2025-02-18                 -1.7                -14.7    -1.7
# 2025-02-19                 -1.7                -14.7    -1.7
#
#             rolling_3_Sademäärä [mm]  rolling_3_Sademäärä [mm]_pct  ...  \
# date                                                                ...
# 1990-01-29                  2.733333                     -0.158537  ...
# 1990-01-30                  2.900000                     -0.793103  ...
# 1990-01-31                  2.100000                      0.619048  ...
# 1990-02-01                  1.500000                     -0.666667  ...
# 1990-02-02                  2.566667                      0.480519  ...
# ...                              ...                           ...  ...
# 2025-02-15                 -1.000000                     -0.000000  ...
# 2025-02-16                  0.100000                     22.000000  ...
# 2025-02-17                  0.100000                    -11.000000  ...
# 2025-02-18                  0.533333                     -0.437500  ...
# 2025-02-19                 -0.133333                     -3.250000  ...
#
#             month_avg_Sademäärä [mm]  day_avg_Sademäärä [mm]  \
# date
# 1990-01-29                  4.906667                2.300000
# 1990-01-30                  4.637500                0.600000
# 1990-01-31                  4.564706                3.400000
# 1990-02-01                  0.500000                0.500000
# 1990-02-02                  2.150000                3.800000
# ...                              ...                     ...
# 2025-02-15                  1.409462                1.305556
# 2025-02-16                  1.410348                2.227778
# 2025-02-17                  1.407952                1.936111
# 2025-02-18                  1.406852                0.638889
# 2025-02-19                  1.405754                1.305556
#
#             month_avg_Lumensyvyys [cm]  day_avg_Lumensyvyys [cm]  \
# date
# 1990-01-29                   32.266667                 33.000000
# 1990-01-30                   32.062500                 29.000000
# 1990-01-31                   31.882353                 29.000000
# 1990-02-01                   26.000000                 26.000000
# 1990-02-02                   24.500000                 23.000000
# ...                                ...                       ...
# 2025-02-15                   22.607570                 22.000000
# 2025-02-16                   22.587065                 22.194444
# 2025-02-17                   22.571571                 23.000000
# 2025-02-18                   22.555114                 23.833333
# 2025-02-19                   22.537698                 23.722222
#
#             month_avg_Ilman keskilämpötila [°C]  \
# date
# 1990-01-29                            -3.046667
# 1990-01-30                            -2.812500
# 1990-01-31                            -2.582353
# 1990-02-01                             2.200000
# 1990-02-02                             2.250000
# ...                                         ...
# 2025-02-15                            -4.533665
# 2025-02-16                            -4.539801
# 2025-02-17                            -4.543638
# 2025-02-18                            -4.544886
# 2025-02-19                            -4.546131
#
#             day_avg_Ilman keskilämpötila [°C]  month_avg_Ylin lämpötila [°C]  \
# date
# 1990-01-29                           1.300000                       0.366667
# 1990-01-30                           0.700000                       0.468750
# 1990-01-31                           1.100000                       0.570588
# 1990-02-01                           2.200000                       3.600000
# 1990-02-02                           2.300000                       3.400000
# ...                                       ...                            ...
# 2025-02-15                          -4.325000                      -1.727092
# 2025-02-16                          -4.227778                      -1.732040
# 2025-02-17                          -4.336111                      -1.734990
# 2025-02-18                          -5.130556                      -1.734955
# 2025-02-19                          -4.747222                      -1.734921
#
#             day_avg_Ylin lämpötila [°C]  month_avg_Alin lämpötila [°C]  \
# date
# 1990-01-29                     2.600000                      -7.640000
# 1990-01-30                     2.000000                      -7.187500
# 1990-01-31                     2.200000                      -6.770588
# 1990-02-01                     3.600000                       1.200000
# 1990-02-02                     3.200000                       1.250000
# ...                                 ...                            ...
# 2025-02-15                    -1.380556                      -7.598108
# 2025-02-16                    -1.766667                      -7.606667
# 2025-02-17                    -1.513889                      -7.612127
# 2025-02-18                    -1.858333                      -7.619166
# 2025-02-19                    -1.900000                      -7.626190
#
#             day_avg_Alin lämpötila [°C]
# date
# 1990-01-29                    -0.400000
# 1990-01-30                    -0.400000
# 1990-01-31                    -0.100000
# 1990-02-01                     1.200000
# 1990-02-02                     1.300000
# ...                                 ...
# 2025-02-15                    -7.150000
# 2025-02-16                    -7.141667
# 2025-02-17                    -6.797222
# 2025-02-18                    -8.925000
# 2025-02-19                    -8.105556
#
# [12806 rows x 38 columns]

# %%
hki.apply(pd.isnull).sum() #Missing values due to division with 0
# Out:
# Havaintoasema                                 0
# Aika [Paikallinen aika]                       0
# Sademäärä [mm]                                0
# Lumensyvyys [cm]                              0
# Ilman keskilämpötila [°C]                     0
# Ylin lämpötila [°C]                           0
# Alin lämpötila [°C]                           0
# Target                                        0
# rolling_3_Sademäärä [mm]                      0
# rolling_3_Sademäärä [mm]_pct                 49
# rolling_3_Lumensyvyys [cm]                    0
# rolling_3_Lumensyvyys [cm]_pct              467
# rolling_3_Ilman keskilämpötila [°C]           0
# rolling_3_Ilman keskilämpötila [°C]_pct       0
# rolling_3_Ylin lämpötila [°C]                 0
# rolling_3_Ylin lämpötila [°C]_pct             0
# rolling_3_Alin lämpötila [°C]                 0
# rolling_3_Alin lämpötila [°C]_pct             0
# rolling_14_Sademäärä [mm]                     0
# rolling_14_Sademäärä [mm]_pct                 0
# rolling_14_Lumensyvyys [cm]                   0
# rolling_14_Lumensyvyys [cm]_pct              39
# rolling_14_Ilman keskilämpötila [°C]          0
# rolling_14_Ilman keskilämpötila [°C]_pct      0
# rolling_14_Ylin lämpötila [°C]                0
# rolling_14_Ylin lämpötila [°C]_pct            0
# rolling_14_Alin lämpötila [°C]                0
# rolling_14_Alin lämpötila [°C]_pct            0
# month_avg_Sademäärä [mm]                      0
# day_avg_Sademäärä [mm]                        0
# month_avg_Lumensyvyys [cm]                    0
# day_avg_Lumensyvyys [cm]                      0
# month_avg_Ilman keskilämpötila [°C]           0
# day_avg_Ilman keskilämpötila [°C]             0
# month_avg_Ylin lämpötila [°C]                 0
# day_avg_Ylin lämpötila [°C]                   0
# month_avg_Alin lämpötila [°C]                 0
# day_avg_Alin lämpötila [°C]                   0
# dtype: int64

# %%
hki = hki.fillna(0)

# %%
hki.apply(pd.isnull).sum()
# Out:
# Havaintoasema                               0
# Aika [Paikallinen aika]                     0
# Sademäärä [mm]                              0
# Lumensyvyys [cm]                            0
# Ilman keskilämpötila [°C]                   0
# Ylin lämpötila [°C]                         0
# Alin lämpötila [°C]                         0
# Target                                      0
# rolling_3_Sademäärä [mm]                    0
# rolling_3_Sademäärä [mm]_pct                0
# rolling_3_Lumensyvyys [cm]                  0
# rolling_3_Lumensyvyys [cm]_pct              0
# rolling_3_Ilman keskilämpötila [°C]         0
# rolling_3_Ilman keskilämpötila [°C]_pct     0
# rolling_3_Ylin lämpötila [°C]               0
# rolling_3_Ylin lämpötila [°C]_pct           0
# rolling_3_Alin lämpötila [°C]               0
# rolling_3_Alin lämpötila [°C]_pct           0
# rolling_14_Sademäärä [mm]                   0
# rolling_14_Sademäärä [mm]_pct               0
# rolling_14_Lumensyvyys [cm]                 0
# rolling_14_Lumensyvyys [cm]_pct             0
# rolling_14_Ilman keskilämpötila [°C]        0
# rolling_14_Ilman keskilämpötila [°C]_pct    0
# rolling_14_Ylin lämpötila [°C]              0
# rolling_14_Ylin lämpötila [°C]_pct          0
# rolling_14_Alin lämpötila [°C]              0
# rolling_14_Alin lämpötila [°C]_pct          0
# month_avg_Sademäärä [mm]                    0
# day_avg_Sademäärä [mm]                      0
# month_avg_Lumensyvyys [cm]                  0
# day_avg_Lumensyvyys [cm]                    0
# month_avg_Ilman keskilämpötila [°C]         0
# day_avg_Ilman keskilämpötila [°C]           0
# month_avg_Ylin lämpötila [°C]               0
# day_avg_Ylin lämpötila [°C]                 0
# month_avg_Alin lämpötila [°C]               0
# day_avg_Alin lämpötila [°C]                 0
# dtype: int64

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["Sademäärä [mm]", "Lumensyvyys [cm]", "Ilman keskilämpötila [°C]","Ylin lämpötila [°C]", "Alin lämpötila [°C]"]:
    hki[f"month_avg_{col}"] = hki[col].groupby(hki.index.month, group_keys=False).apply(expand_mean)
    hki[f"day_avg_{col}"] = hki[col].groupby(hki.index.day_of_year, group_keys=False).apply(expand_mean)

# %%
hki
# Out:
#                                  Havaintoasema Aika [Paikallinen aika]  \
# date
# 1990-01-29  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-30  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-01-31  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-02-01  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 1990-02-02  Vantaa Helsinki-Vantaan lentoasema                   02:00
# ...                                        ...                     ...
# 2025-02-15  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-16  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-17  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-18  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2025-02-19  Vantaa Helsinki-Vantaan lentoasema                   02:00
#
#             Sademäärä [mm]  Lumensyvyys [cm]  Ilman keskilämpötila [°C]  \
# date
# 1990-01-29             2.3              33.0                        1.3
# 1990-01-30             0.6              29.0                        0.7
# 1990-01-31             3.4              29.0                        1.1
# 1990-02-01             0.5              26.0                        2.2
# 1990-02-02             3.8              23.0                        2.3
# ...                    ...               ...                        ...
# 2025-02-15            -1.0               2.0                       -8.4
# 2025-02-16             2.3               2.0                      -10.7
# 2025-02-17            -1.0               7.0                       -8.4
# 2025-02-18             0.3               6.0                       -5.8
# 2025-02-19             0.3               5.0                       -5.8
#
#             Ylin lämpötila [°C]  Alin lämpötila [°C]  Target  \
# date
# 1990-01-29                  2.6                 -0.4     2.0
# 1990-01-30                  2.0                 -0.4     2.2
# 1990-01-31                  2.2                 -0.1     3.6
# 1990-02-01                  3.6                  1.2     3.2
# 1990-02-02                  3.2                  1.3     2.5
# ...                         ...                  ...     ...
# 2025-02-15                 -6.2                -12.5    -6.7
# 2025-02-16                 -6.7                -16.2    -4.7
# 2025-02-17                 -4.7                -13.1    -1.7
# 2025-02-18                 -1.7                -14.7    -1.7
# 2025-02-19                 -1.7                -14.7    -1.7
#
#             rolling_3_Sademäärä [mm]  rolling_3_Sademäärä [mm]_pct  ...  \
# date                                                                ...
# 1990-01-29                  2.733333                     -0.158537  ...
# 1990-01-30                  2.900000                     -0.793103  ...
# 1990-01-31                  2.100000                      0.619048  ...
# 1990-02-01                  1.500000                     -0.666667  ...
# 1990-02-02                  2.566667                      0.480519  ...
# ...                              ...                           ...  ...
# 2025-02-15                 -1.000000                     -0.000000  ...
# 2025-02-16                  0.100000                     22.000000  ...
# 2025-02-17                  0.100000                    -11.000000  ...
# 2025-02-18                  0.533333                     -0.437500  ...
# 2025-02-19                 -0.133333                     -3.250000  ...
#
#             month_avg_Sademäärä [mm]  day_avg_Sademäärä [mm]  \
# date
# 1990-01-29                  2.300000                2.300000
# 1990-01-30                  1.450000                0.600000
# 1990-01-31                  2.100000                3.400000
# 1990-02-01                  0.500000                0.500000
# 1990-02-02                  2.150000                3.800000
# ...                              ...                     ...
# 2025-02-15                  1.409462                1.305556
# 2025-02-16                  1.410348                2.227778
# 2025-02-17                  1.407952                1.936111
# 2025-02-18                  1.406852                0.638889
# 2025-02-19                  1.405754                1.305556
#
#             month_avg_Lumensyvyys [cm]  day_avg_Lumensyvyys [cm]  \
# date
# 1990-01-29                   33.000000                 33.000000
# 1990-01-30                   31.000000                 29.000000
# 1990-01-31                   30.333333                 29.000000
# 1990-02-01                   26.000000                 26.000000
# 1990-02-02                   24.500000                 23.000000
# ...                                ...                       ...
# 2025-02-15                   22.607570                 22.000000
# 2025-02-16                   22.587065                 22.194444
# 2025-02-17                   22.571571                 23.000000
# 2025-02-18                   22.555114                 23.833333
# 2025-02-19                   22.537698                 23.722222
#
#             month_avg_Ilman keskilämpötila [°C]  \
# date
# 1990-01-29                             1.300000
# 1990-01-30                             1.000000
# 1990-01-31                             1.033333
# 1990-02-01                             2.200000
# 1990-02-02                             2.250000
# ...                                         ...
# 2025-02-15                            -4.533665
# 2025-02-16                            -4.539801
# 2025-02-17                            -4.543638
# 2025-02-18                            -4.544886
# 2025-02-19                            -4.546131
#
#             day_avg_Ilman keskilämpötila [°C]  month_avg_Ylin lämpötila [°C]  \
# date
# 1990-01-29                           1.300000                       2.600000
# 1990-01-30                           0.700000                       2.300000
# 1990-01-31                           1.100000                       2.266667
# 1990-02-01                           2.200000                       3.600000
# 1990-02-02                           2.300000                       3.400000
# ...                                       ...                            ...
# 2025-02-15                          -4.325000                      -1.727092
# 2025-02-16                          -4.227778                      -1.732040
# 2025-02-17                          -4.336111                      -1.734990
# 2025-02-18                          -5.130556                      -1.734955
# 2025-02-19                          -4.747222                      -1.734921
#
#             day_avg_Ylin lämpötila [°C]  month_avg_Alin lämpötila [°C]  \
# date
# 1990-01-29                     2.600000                      -0.400000
# 1990-01-30                     2.000000                      -0.400000
# 1990-01-31                     2.200000                      -0.300000
# 1990-02-01                     3.600000                       1.200000
# 1990-02-02                     3.200000                       1.250000
# ...                                 ...                            ...
# 2025-02-15                    -1.380556                      -7.598108
# 2025-02-16                    -1.766667                      -7.606667
# 2025-02-17                    -1.513889                      -7.612127
# 2025-02-18                    -1.858333                      -7.619166
# 2025-02-19                    -1.900000                      -7.626190
#
#             day_avg_Alin lämpötila [°C]
# date
# 1990-01-29                    -0.400000
# 1990-01-30                    -0.400000
# 1990-01-31                    -0.100000
# 1990-02-01                     1.200000
# 1990-02-02                     1.300000
# ...                                 ...
# 2025-02-15                    -7.150000
# 2025-02-16                    -7.141667
# 2025-02-17                    -6.797222
# 2025-02-18                    -8.925000
# 2025-02-19                    -8.105556
#
# [12806 rows x 38 columns]

# %%
predictors = [
    "Sademäärä [mm]",
    "Lumensyvyys [cm]",
    "Ilman keskilämpötila [°C]",
    "Ylin lämpötila [°C]",
    "Alin lämpötila [°C]"
]

# %%
predictors
# Out:
# ['Sademäärä [mm]',
#  'Lumensyvyys [cm]',
#  'Ilman keskilämpötila [°C]',
#  'Ylin lämpötila [°C]',
#  'Alin lämpötila [°C]']

# %%
predictions = backtest(hki, rr, predictors)
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 1.945793669209279

# %%
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 1.945793669209279

# %%
predictions.sort_values("diff",ascending=False)
# Out:
#             actual  prediction       diff
# date
# 2006-01-22    -2.5  -18.219219  15.719219
# 2024-01-07    -3.1  -18.324178  15.224178
# 2017-01-06    -1.3  -15.109756  13.809756
# 2003-01-10    -3.6  -16.838947  13.238947
# 2014-12-29     0.4  -12.706232  13.106232
# ...            ...         ...        ...
# 2016-09-11    20.3   20.299027   0.000973
# 2012-08-16    23.2   23.199464   0.000536
# 2018-07-28    28.3   28.300394   0.000394
# 2020-09-14    17.8   17.800293   0.000293
# 2015-09-25    16.9   16.900001   0.000001
#
# [9156 rows x 3 columns]

# %%
hki.loc["2006-01-12":"2006-01-30"] #check anomalies in temp regard to jan 22 2006
# Out:
#                                  Havaintoasema Aika [Paikallinen aika]  \
# date
# 2006-01-12  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-13  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-14  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-15  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-16  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-17  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-18  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-19  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-20  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-21  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-22  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-23  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-24  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-25  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-26  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-27  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-28  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-29  Vantaa Helsinki-Vantaan lentoasema                   02:00
# 2006-01-30  Vantaa Helsinki-Vantaan lentoasema                   02:00
#
#             Sademäärä [mm]  Lumensyvyys [cm]  Ilman keskilämpötila [°C]  \
# date
# 2006-01-12            -1.0               0.0                        2.0
# 2006-01-13             0.0               0.0                        0.3
# 2006-01-14            -1.0               0.0                        0.2
# 2006-01-15             0.0               0.0                       -0.5
# 2006-01-16             0.1               0.0                       -1.1
# 2006-01-17             0.7               0.0                       -3.8
# 2006-01-18             0.1               2.0                      -14.8
# 2006-01-19             0.1               2.0                      -20.7
# 2006-01-20             0.8               2.0                      -20.4
# 2006-01-21             0.1               2.0                      -20.5
# 2006-01-22             0.0               1.0                      -22.0
# 2006-01-23             1.9               1.0                      -10.1
# 2006-01-24             0.1               3.0                       -1.4
# 2006-01-25             0.1               3.0                       -0.5
# 2006-01-26             0.0               3.0                       -3.8
# 2006-01-27             0.0               3.0                        0.3
# 2006-01-28             0.1               1.0                       -3.6
# 2006-01-29             0.2               2.0                        0.4
# 2006-01-30             0.0               0.0                        0.7
#
#             Ylin lämpötila [°C]  Alin lämpötila [°C]  Target  \
# date
# 2006-01-12                  3.5                  1.0     2.2
# 2006-01-13                  2.2                 -3.6     1.7
# 2006-01-14                  1.7                 -1.4     2.1
# 2006-01-15                  2.1                 -1.9    -0.2
# 2006-01-16                 -0.2                 -1.6    -0.4
# 2006-01-17                 -0.4                 -7.3    -7.3
# 2006-01-18                 -7.3                -18.3   -17.6
# 2006-01-19                -17.6                -22.0   -17.9
# 2006-01-20                -17.9                -22.8   -18.2
# 2006-01-21                -18.2                -22.3   -19.0
# 2006-01-22                -19.0                -24.3    -2.5
# 2006-01-23                 -2.5                -23.5    -0.8
# 2006-01-24                 -0.8                 -2.5     0.3
# 2006-01-25                  0.3                 -1.7     0.0
# 2006-01-26                  0.0                 -6.7     2.0
# 2006-01-27                  2.0                 -3.2    -0.5
# 2006-01-28                 -0.5                 -6.6     2.1
# 2006-01-29                  2.1                 -2.3     3.4
# 2006-01-30                  3.4                 -1.9    -1.8
#
#             rolling_3_Sademäärä [mm]  rolling_3_Sademäärä [mm]_pct  ...  \
# date                                                                ...
# 2006-01-12                  1.000000                     -2.000000  ...
# 2006-01-13                  0.533333                     -1.000000  ...
# 2006-01-14                 -0.666667                      0.500000  ...
# 2006-01-15                 -0.333333                     -1.000000  ...
# 2006-01-16                 -0.300000                     -1.333333  ...
# 2006-01-17                  0.266667                      1.625000  ...
# 2006-01-18                  0.300000                     -0.666667  ...
# 2006-01-19                  0.300000                     -0.666667  ...
# 2006-01-20                  0.333333                      1.400000  ...
# 2006-01-21                  0.333333                     -0.700000  ...
# 2006-01-22                  0.300000                     -1.000000  ...
# 2006-01-23                  0.666667                      1.850000  ...
# 2006-01-24                  0.666667                     -0.850000  ...
# 2006-01-25                  0.700000                     -0.857143  ...
# 2006-01-26                  0.066667                     -1.000000  ...
# 2006-01-27                  0.033333                     -1.000000  ...
# 2006-01-28                  0.033333                      2.000000  ...
# 2006-01-29                  0.100000                      1.000000  ...
# 2006-01-30                  0.100000                     -1.000000  ...
#
#             month_avg_Sademäärä [mm]  day_avg_Sademäärä [mm]  \
# date
# 2006-01-12                  1.672292                1.931250
# 2006-01-13                  1.668815                2.300000
# 2006-01-14                  1.663278                2.150000
# 2006-01-15                  1.659834                1.512500
# 2006-01-16                  1.656612                2.137500
# 2006-01-17                  1.654639                0.950000
# 2006-01-18                  1.651440                0.350000
# 2006-01-19                  1.648255                0.468750
# 2006-01-20                  1.646516                2.687500
# 2006-01-21                  1.643354                1.250000
# 2006-01-22                  1.640000                1.931250
# 2006-01-23                  1.640530                3.012500
# 2006-01-24                  1.637398                1.837500
# 2006-01-25                  1.634280                1.731250
# 2006-01-26                  1.630972                0.625000
# 2006-01-27                  1.627677                1.668750
# 2006-01-28                  1.624597                0.793750
# 2006-01-29                  1.621730                1.647059
# 2006-01-30                  1.618474                1.000000
#
#             month_avg_Lumensyvyys [cm]  day_avg_Lumensyvyys [cm]  \
# date
# 2006-01-12                    9.289583                  7.562500
# 2006-01-13                    9.270270                  8.187500
# 2006-01-14                    9.251037                  7.625000
# 2006-01-15                    9.231884                  7.812500
# 2006-01-16                    9.212810                  7.000000
# 2006-01-17                    9.193814                  7.562500
# 2006-01-18                    9.179012                  7.000000
# 2006-01-19                    9.164271                  6.812500
# 2006-01-20                    9.149590                  6.812500
# 2006-01-21                    9.134969                  8.250000
# 2006-01-22                    9.118367                  8.000000
# 2006-01-23                    9.101833                  8.000000
# 2006-01-24                    9.089431                 12.250000
# 2006-01-25                    9.077079                 11.875000
# 2006-01-26                    9.064777                 12.187500
# 2006-01-27                    9.052525                 11.875000
# 2006-01-28                    9.036290                 12.125000
# 2006-01-29                    9.022133                 13.705882
# 2006-01-30                    9.004016                 14.294118
#
#             month_avg_Ilman keskilämpötila [°C]  \
# date
# 2006-01-12                            -3.772917
# 2006-01-13                            -3.764449
# 2006-01-14                            -3.756224
# 2006-01-15                            -3.749482
# 2006-01-16                            -3.744008
# 2006-01-17                            -3.744124
# 2006-01-18                            -3.766872
# 2006-01-19                            -3.801643
# 2006-01-20                            -3.835656
# 2006-01-21                            -3.869734
# 2006-01-22                            -3.906735
# 2006-01-23                            -3.919348
# 2006-01-24                            -3.914228
# 2006-01-25                            -3.907302
# 2006-01-26                            -3.907085
# 2006-01-27                            -3.898586
# 2006-01-28                            -3.897984
# 2006-01-29                            -3.889336
# 2006-01-30                            -3.880120
#
#             day_avg_Ilman keskilämpötila [°C]  month_avg_Ylin lämpötila [°C]  \
# date
# 2006-01-12                          -2.862500                      -1.294375
# 2006-01-13                          -2.762500                      -1.287110
# 2006-01-14                          -1.912500                      -1.280913
# 2006-01-15                          -1.050000                      -1.273913
# 2006-01-16                          -0.612500                      -1.271694
# 2006-01-17                          -1.362500                      -1.269897
# 2006-01-18                          -2.612500                      -1.282305
# 2006-01-19                          -4.231250                      -1.315811
# 2006-01-20                          -5.506250                      -1.349795
# 2006-01-21                          -4.537500                      -1.384254
# 2006-01-22                          -4.081250                      -1.420204
# 2006-01-23                          -3.500000                      -1.422403
# 2006-01-24                          -4.568750                      -1.421138
# 2006-01-25                          -4.350000                      -1.417647
# 2006-01-26                          -4.662500                      -1.414777
# 2006-01-27                          -5.625000                      -1.407879
# 2006-01-28                          -6.200000                      -1.406048
# 2006-01-29                          -6.505882                      -1.398994
# 2006-01-30                          -6.776471                      -1.389357
#
#             day_avg_Ylin lämpötila [°C]  month_avg_Alin lämpötila [°C]  \
# date
# 2006-01-12                    -0.831250                      -6.732917
# 2006-01-13                    -0.618750                      -6.726403
# 2006-01-14                     0.250000                      -6.715353
# 2006-01-15                     0.650000                      -6.705383
# 2006-01-16                     1.343750                      -6.694835
# 2006-01-17                     0.568750                      -6.696082
# 2006-01-18                    -0.268750                      -6.719959
# 2006-01-19                    -1.868750                      -6.751335
# 2006-01-20                    -2.306250                      -6.784221
# 2006-01-21                    -2.412500                      -6.815951
# 2006-01-22                    -2.200000                      -6.851633
# 2006-01-23                    -0.718750                      -6.885540
# 2006-01-24                    -1.681250                      -6.876626
# 2006-01-25                    -1.568750                      -6.866126
# 2006-01-26                    -2.043750                      -6.865789
# 2006-01-27                    -2.843750                      -6.858384
# 2006-01-28                    -2.593750                      -6.857863
# 2006-01-29                    -3.652941                      -6.848692
# 2006-01-30                    -3.182353                      -6.838755
#
#             day_avg_Alin lämpötila [°C]
# date
# 2006-01-12                    -5.081250
# 2006-01-13                    -5.562500
# 2006-01-14                    -5.706250
# 2006-01-15                    -3.331250
# 2006-01-16                    -3.375000
# 2006-01-17                    -3.987500
# 2006-01-18                    -4.731250
# 2006-01-19                    -6.043750
# 2006-01-20                    -8.625000
# 2006-01-21                    -7.393750
# 2006-01-22                    -6.193750
# 2006-01-23                    -6.725000
# 2006-01-24                    -7.225000
# 2006-01-25                    -8.450000
# 2006-01-26                    -7.506250
# 2006-01-27                    -8.025000
# 2006-01-28                   -10.093750
# 2006-01-29                    -9.894118
# 2006-01-30                   -10.641176
#
# [19 rows x 38 columns]

# %%
(predictions["diff"].round().value_counts().sort_index()) #Showing counts of different differences
# Out:
# diff
# 0.0     1545
# 1.0     2898
# 2.0     2108
# 3.0     1232
# 4.0      694
# 5.0      333
# 6.0      176
# 7.0       88
# 8.0       35
# 9.0       17
# 10.0      14
# 11.0       5
# 12.0       3
# 13.0       5
# 14.0       1
# 15.0       1
# 16.0       1
# Name: count, dtype: int64

# %%
(predictions["diff"].round().value_counts().sort_index().plot())
# Out:
# <Axes: xlabel='diff'>

# %%
predictions
# Out:
#             actual  prediction      diff
# date
# 2000-01-27    -1.8    0.802008  2.602008
# 2000-01-28     1.1   -0.964314  2.064314
# 2000-01-29     1.7    3.065645  1.365645
# 2000-01-30    -0.3    1.998039  2.298039
# 2000-01-31    -0.2   -1.071608  0.871608
# ...            ...         ...       ...
# 2025-02-15    -6.7   -4.823697  1.876303
# 2025-02-16    -4.7   -5.833321  1.133321
# 2025-02-17    -1.7   -3.985400  2.285400
# 2025-02-18    -1.7    0.150179  1.850179
# 2025-02-19    -1.7    0.160213  1.860213
#
# [9156 rows x 3 columns]
